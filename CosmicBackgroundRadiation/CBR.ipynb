# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['beta']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
data = array(pd.read_csv('CBR.data', sep = ' ', encoding = 'utf8', na_values = ['#DIV/0!'] ))
data = data.T[[0,1]][:].T
#Constantes
h = 6.62606896*10**-34
c = 2.99792458*10**8
kB = 1.3806488*10**-23
for k in range(len(data)):
    data[k][1] = (10**-20)*data[k][1]
    data[k][0] = 10**2*c*data[k][0]

# %%
data = data.T
mx, my = max(data[0]),max(data[1])/2
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(data[0], data[1])
ax.plot(data[0], data[1], 'k')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
ax.set_title('Radiacion cosmica de fondo')
ax.set_xlabel('Frecuencia(Hz)')
ax.set_ylabel('Intensidad Espectral de Radiacion(W/m2Hzstrad)')  
plt.xlim(0, 1.1*max(data[0]))
plt.ylim(0, 11*max(data[1])/10)
plt.show()
data = data.T

print data
# Out:
# [[  6.80528880e+10   2.00723000e-18]
#  [  8.15435486e+10   2.49508000e-18]
#  [  9.53340016e+10   2.93024000e-18]
#  [  1.08824662e+11   3.27770000e-18]
#  [  1.22315323e+11   3.54081000e-18]
#  [  1.36105776e+11   3.72079000e-18]
#  [  1.49596437e+11   3.81493000e-18]
#  [  1.63386890e+11   3.83478000e-18]
#  [  1.76877550e+11   3.78901000e-18]
#  [  1.90368211e+11   3.68833000e-18]
#  [  2.04158664e+11   3.54063000e-18]
#  [  2.17649325e+11   3.36278000e-18]
#  [  2.31139985e+11   3.16076000e-18]
#  [  2.44930438e+11   2.93924000e-18]
#  [  2.58421099e+11   2.71432000e-18]
#  [  2.72211552e+11   2.48239000e-18]
#  [  2.85702212e+11   2.25940000e-18]
#  [  2.99192873e+11   2.04327000e-18]
#  [  3.12983326e+11   1.83262000e-18]
#  [  3.26473987e+11   1.63830000e-18]
#  [  3.39964647e+11   1.45750000e-18]
#  [  3.53755100e+11   1.28835000e-18]
#  [  3.67245761e+11   1.13568000e-18]
#  [  3.81036214e+11   9.94510000e-19]
#  [  3.94526875e+11   8.70360000e-19]
# ...

# %%
beta = 2*h/(c**2)
temp1 = (h/kB)*data.T[0]
temp2 = np.log((beta*(data.T[0]**3)/data.T[1]) + 1)
linearT = temp1/temp2
tempFreq = np.array([data.T[0], linearT]).T
print tempFreq
# Out:
# [[  6.80528880e+10   2.72505694e+00]
#  [  8.15435486e+10   2.72506940e+00]
#  [  9.53340016e+10   2.72508458e+00]
#  [  1.08824662e+11   2.72503085e+00]
#  [  1.22315323e+11   2.72507600e+00]
#  [  1.36105776e+11   2.72493368e+00]
#  [  1.49596437e+11   2.72494003e+00]
#  [  1.63386890e+11   2.72499320e+00]
#  [  1.76877550e+11   2.72508542e+00]
#  [  1.90368211e+11   2.72502471e+00]
#  [  2.04158664e+11   2.72501050e+00]
#  [  2.17649325e+11   2.72504201e+00]
#  [  2.31139985e+11   2.72496887e+00]
#  [  2.44930438e+11   2.72503207e+00]
#  [  2.58421099e+11   2.72503214e+00]
#  [  2.72211552e+11   2.72496657e+00]
#  [  2.85702212e+11   2.72503574e+00]
#  [  2.99192873e+11   2.72504536e+00]
#  [  3.12983326e+11   2.72504426e+00]
#  [  3.26473987e+11   2.72493119e+00]
#  [  3.39964647e+11   2.72487066e+00]
#  [  3.53755100e+11   2.72521113e+00]
#  [  3.67245761e+11   2.72503658e+00]
#  [  3.81036214e+11   2.72498869e+00]
#  [  3.94526875e+11   2.72504088e+00]
# ...

# %%
prom = linearT.mean(axis = 0)
desvest = linearT.std(axis = 0)
print "Promedio: "
print prom
print "Desviacion estandar: "
print desvest
# Out:
# Promedio:
# 2.72445805538
# Desviacion estandar:
# 0.00339763649547

# %%
data = data.T
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(data[0], linearT)
ax.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
ax.set_title('Temperatura del universo')
ax.set_xlabel('Frecuencia(Hz)')
ax.set_ylabel('Temperatura(K)')  

plt.show()
data = data.T
